# %%
import torch
import torchvision
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! python mnist.py --model_type netregular
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.300039
# Train Epoch: 1 [640/60000 (1%)]	Loss: 0.962228
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.576719
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.328246
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.556539
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.385720
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.183584
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.173256
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.073014
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.168599
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.117510
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.177806
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 0.063909
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 0.297568
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 0.101936
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.134729
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 0.122718
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 0.402550
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 0.099138
# ...

# %%
net_regular_results = [98.7, 98.86, 99.01, 98.84, 99.1, 99.1, 99.03, 99.06, 99.22, 99.06]

# %%
! python mnist.py --model_type netkhrulkov
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.821708
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.715499
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.449146
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.325223
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.154044
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.051965
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 1.998835
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.701066
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.877297
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.954246
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.445636
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.365505
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.469750
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.407714
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.688919
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.121891
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.330888
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.219709
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.131662
# ...

# %%
net_khrulkov_results = [94.93, 96.48, 97.64, 96.68, 98.08, 97.96, 98.15, 98.11, 97.96, 98.5]

# %%
! python mnist.py --model_type nethypconv
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.721151
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.687188
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.448284
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.469285
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.392688
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.211291
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.317843
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.081559
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.028906
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.247358
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.796557
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.689519
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.756679
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.792162
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.913363
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.351300
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.578909
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.596008
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.508691
# ...

# %%
net_hyp_conv_results = [88.68, 93.2, 94.45, 94.35, 95.09, 95.66, 95.95, 95.61, 95.97, 96.32]

# %%
! python mnist.py --model_type nethypconv2
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.719104
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.637499
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.432627
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.405412
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.338672
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.315961
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.278098
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.108624
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.987243
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.415981
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.072405
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.777906
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.841883
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.999822
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.139339
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.678667
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.813051
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.879374
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.758521
# ...

# %%
net_hyp_conv_2_results = [48.19, 66.6, 81.58, 85.86, 85.01, 79.93, 83.63, 78.46, 81.33, 87.93]

# %%
plt.plot(net_regular_results, label='Net Regular')
plt.plot(net_khrulkov_results, label='Net Khrulkov')
plt.plot(net_hyp_conv_results, label='Net Hyp Conv')
plt.plot(net_hyp_conv_2_results, label='Net Hyp Conv 2')

plt.legend()
