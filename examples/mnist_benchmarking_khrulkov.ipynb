# %%
import torch
import torchvision
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
! python mnist.py --model_type netregular
# Out:
# ...
# 26.4MB [00:01, 14.9MB/s]
# Extracting ../data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# ...
# 32.8kB [00:00, 99.3kB/s]
# Extracting ../data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# ...
# 4.42MB [00:00, 4.44MB/s]
# Extracting ../data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# ...
# 8.19kB [00:00, 36.2kB/s]
# Extracting ../data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.290823
# Train Epoch: 1 [640/60000 (1%)]	Loss: 1.241605
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 0.813709
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 0.415009
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 0.819265
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.643488
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 0.637306
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 0.570915
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 0.736636
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 0.639263
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.538715
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 0.529438
# ...

# %%
net_regular_results_mnist = [98.7, 98.86, 99.01, 98.84, 99.1, 99.1, 99.03, 99.06, 99.22, 99.06]
net_regular_results_fmnist = [87.74, 88.6, 89.73, 90.35, 90.36, 89.94, 90.81, 90.88, 91.04, 91.18]

# %%
! python mnist.py --model_type netkhrulkov
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.547264
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.346073
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.273791
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 1.901541
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 1.874385
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 1.876174
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 1.714194
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.662751
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.646750
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.595303
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.446684
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.538390
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.674057
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.559906
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.763525
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.144247
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.303627
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.400301
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.291584
# ...

# %%
net_khrulkov_results_mnist = [94.93, 96.48, 97.64, 96.68, 98.08, 97.96, 98.15, 98.11, 97.96, 98.5]
net_khrulkov_results_fmnist = [73.79, 82.37, 84.67, 86.21, 85.4, 83.2, 85.52, 87.64, 86.49, 88.06]

# %%
! python mnist.py --model_type nethypconv
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.543381
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.429636
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.421628
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.314351
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.291540
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.070297
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.062604
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.996058
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.888765
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.823606
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.832447
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.942988
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.787473
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.804902
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.010171
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.491177
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.522225
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.577460
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.653620
# ...

# %%
net_hyp_conv_results_mnist = [88.68, 93.2, 94.45, 94.35, 95.09, 95.66, 95.95, 95.61, 95.97, 96.32]
net_hyp_conv_results_fmnist = [65.76, 75.78, 79.57, 78.35, 82.72, 82.02, 82.43, 83.81, 84.91, 85.41]

# %%
! python mnist.py --model_type nethypconv2
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.546417
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.415336
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.388571
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.130245
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.145459
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.026881
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 1.889278
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.952688
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.829628
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.908606
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.840610
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.906541
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.834228
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.916149
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.134763
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.554473
# Train Epoch: 1 [10240/60000 (17%)]	Loss: 1.587657
# Train Epoch: 1 [10880/60000 (18%)]	Loss: 1.644426
# Train Epoch: 1 [11520/60000 (19%)]	Loss: 1.748086
# ...

# %%
net_hyp_conv_2_results_mnist = [48.19, 66.6, 81.58, 85.86, 85.01, 79.93, 83.63, 78.46, 81.33, 87.93]
net_hyp_conv_2_results_fmnist = [55.58, 50.9, 58.8, 60.79, 64.33, 63.31, 65.46, 68.34, 68.95, 70.2]

# %%
plt.title('MNIST results')
plt.plot(net_regular_results_mnist, label='Net Regular')
plt.plot(net_khrulkov_results_mnist, label='Net Khrulkov')
plt.plot(net_hyp_conv_results_mnist, label='Net Hyp Conv')
plt.plot(net_hyp_conv_2_results_mnist, label='Net Hyp Conv 2')

plt.legend()

# %%
plt.title('F-MNIST results')
plt.plot(net_regular_results_fmnist, label='Net Regular')
plt.plot(net_khrulkov_results_fmnist, label='Net Khrulkov')
plt.plot(net_hyp_conv_results_fmnist, label='Net Hyp Conv')
plt.plot(net_hyp_conv_2_results_fmnist, label='Net Hyp Conv 2')

plt.legend()
